# %%
a,b,c,d = 1,2.2,True,4+2j
print(type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'bool'> <class 'complex'>

# %%
print('Ru\noob')
print(r'Ru\noob')
# Out:
# Ru
# oob
# Ru\noob

# %%
word = 'Python'
print(word[0], word[5])

print(word[-1], word[-6])
# Out:
# P n
# n P

# %%
my_list = ['abcd', 786, 2.23, 'runoob', 70.2]  # 避免使用 list 作为变量名，会覆盖内置类型
tinylist = [123, 'runoob']

print(my_list)             # 打印整个列表：['abcd', 786, 2.23, 'runoob', 70.2]
print(my_list[0])          # 打印第一个元素（索引 0）：abcd
print(my_list[1:3])        # 打印索引 1 和 2 的元素（不含索引 3）：[786, 2.23]
print(my_list[2:])         # 打印从索引 2 开始到末尾的所有元素：[2.23, 'runoob', 70.2]
print(tinylist * 2)        # 重复打印 tinylist 两次：[123, 'runoob', 123, 'runoob']
print(my_list + tinylist)  # 拼接两个列表
# Out:
# ['abcd', 786, 2.23, 'runoob', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'runoob', 70.2]
# [123, 'runoob', 123, 'runoob']
# ['abcd', 786, 2.23, 'runoob', 70.2, 123, 'runoob']

# %%
def reverseWords(input):
    
    # 通过空格将字符串分隔，把各个单词分隔为列表
    inputWords = input.split(" ")
    n = len(inputWords)
    # inputWords[-1::-1] 三个参数说明：
    # 第一个参数 -1 表示从最后一个元素开始
    # 第二个参数为空，表示遍历到列表边界
    # 第三个参数 负数: right->right;正数: left->right;
    reverseInputWords = inputWords[-1::-1]

    # 重新用空格拼接单词
    output = ' '.join(reverseInputWords)

    return output
mystr = 'I come from China'
# print(mystr[::-1])
print(reverseWords(mystr))

# %%
my_tuple = ('abcd', 786, 2.23, 'runoob', 70.2)  # 避免使用 tuple 作为变量名
tinytuple = (123, 'runoob')

print(my_tuple)               # 输出完整元组
print(my_tuple[0])            # 输出第一个元素：abcd
print(my_tuple[1:3])          # 输出索引 1 和 2 的元素：(786, 2.23)
print(my_tuple[2:])           # 输出从索引 2 开始的所有元素
print(tinytuple * 2)          # 输出两次 tinytuple
print(my_tuple + tinytuple)   # 连接两个元组
# Out:
# ('abcd', 786, 2.23, 'runoob', 70.2)
# abcd
# (786, 2.23)
# (2.23, 'runoob', 70.2)
# (123, 'runoob', 123, 'runoob')
# ('abcd', 786, 2.23, 'runoob', 70.2, 123, 'runoob')

# %%
sites = {'Google', 'Taobao', 'Runoob', 'Facebook', 'Zhihu', 'Baidu'}

print(sites)   # 输出集合（无序，重复元素会被自动去掉）

# 成员测试
if 'Runoob' in sites:
    print('Runoob 在集合中')
else:
    print('Runoob 不在集合中')

# set 可以进行集合运算
a = set('abracadabra')
b = set('alacazam')

print('a 中的唯一字符',a) 
print('b 中的唯一字符',b)
print('a 和 b 的差集（在 a 中但不在 b 中）',a - b)
print('b 和 a 的差集（在 b 中但不在 a 中）',b - a)
print('a 和 b 的并集（在 a 或 b 中）',a | b)       
print('a 和 b 的交集（同时在 a 和 b 中）',a & b)       
print('a 和 b 的对称差集（在 a 或 b 中，但不同时存在）',a ^ b)
# Out:
# {'Runoob', 'Facebook', 'Baidu', 'Zhihu', 'Google', 'Taobao'}
# Runoob 在集合中
# a 中的唯一字符 {'b', 'a', 'd', 'r', 'c'}
# b 中的唯一字符 {'z', 'l', 'm', 'a', 'c'}
# a 和 b 的差集（在 a 中但不在 b 中） {'d', 'b', 'r'}
# b 和 a 的差集（在 b 中但不在 a 中） {'z', 'm', 'l'}
# a 和 b 的并集（在 a 或 b 中） {'z', 'b', 'l', 'm', 'a', 'd', 'r', 'c'}
# a 和 b 的交集（同时在 a 和 b 中） {'a', 'c'}
# a 和 b 的对称差集（在 a 或 b 中，但不同时存在） {'z', 'd', 'l', 'b', 'm', 'r'}
